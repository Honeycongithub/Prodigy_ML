# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
pd_data = pd.read_csv('Housing_price.csv')

# %%
pd_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 0    -122.23     37.88                  41          880           129.0  \
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
pd_data.shape
# Out:
# (20640, 10)

# %%
pd_data = data.drop(['longitude', 'latitude'], axis=1)

# %%
pd_data.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households
# 0                  41          880           129.0         322         126  \
# 1                  21         7099          1106.0        2401        1138
# 2                  52         1467           190.0         496         177
# 3                  52         1274           235.0         558         219
# 4                  52         1627           280.0         565         259
#
#    median_income ocean_proximity  median_house_value
# 0         8.3252        NEAR BAY              452600
# 1         8.3014        NEAR BAY              358500
# 2         7.2574        NEAR BAY              352100
# 3         5.6431        NEAR BAY              341300
# 4         3.8462        NEAR BAY              342200

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  20433 non-null  int64
#  1   total_rooms         20433 non-null  int64
#  2   total_bedrooms      20433 non-null  float64
#  3   population          20433 non-null  int64
#  4   households          20433 non-null  int64
#  5   median_income       20433 non-null  float64
#  6   ocean_proximity     20433 non-null  object
#  7   median_house_value  20433 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
pd_data.dropna(inplace=True)

# %%
pd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  20433 non-null  int64
#  1   total_rooms         20433 non-null  int64
#  2   total_bedrooms      20433 non-null  float64
#  3   population          20433 non-null  int64
#  4   households          20433 non-null  int64
#  5   median_income       20433 non-null  float64
#  6   ocean_proximity     20433 non-null  object
#  7   median_house_value  20433 non-null  int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.4+ MB

# %%
pd_data.duplicated().sum()
# Out:
# 0

# %%
pd_data.describe()
# Out:
#        housing_median_age   total_rooms  total_bedrooms    population
# count        20433.000000  20433.000000    20433.000000  20433.000000  \
# mean            28.633094   2636.504233      537.870553   1424.946949
# std             12.591805   2185.269567      421.385070   1133.208490
# min              1.000000      2.000000        1.000000      3.000000
# 25%             18.000000   1450.000000      296.000000    787.000000
# 50%             29.000000   2127.000000      435.000000   1166.000000
# 75%             37.000000   3143.000000      647.000000   1722.000000
# max             52.000000  39320.000000     6445.000000  35682.000000
#
#          households  median_income  median_house_value
# count  20433.000000   20433.000000        20433.000000
# mean     499.433465       3.871162       206864.413155
# std      382.299226       1.899291       115435.667099
# min        1.000000       0.499900        14999.000000
# 25%      280.000000       2.563700       119500.000000
# ...

# %% [markdown]
# # Data Visualization

# %%
pd_data.columns = pd_data.columns.to_list()
pd_data.columns
# Out:
# Index(['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
#        'households', 'median_income', 'ocean_proximity', 'median_house_value'],
#       dtype='object')

# %%
pd_data.coll = ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
       'households', 'median_income', 'median_house_value']
pd_data.coll
# Out:
# C:\Users\PATEL TITHI\AppData\Local\Temp\ipykernel_15872\3657120826.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   pd_data.coll = ['housing_median_age', 'total_rooms', 'total_bedrooms', 'population',
# ['housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value']

# %%
pd_data.cat = ['ocean_proximity']
pd_data.cat
# Out:
# C:\Users\PATEL TITHI\AppData\Local\Temp\ipykernel_15872\2727287555.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   pd_data.cat = ['ocean_proximity']
# ['ocean_proximity']

# %%
pd_data.cat
# Out:
# ['ocean_proximity']

# %%
for i in pd_data.coll:
    sns.histplot(pd_data[i])
    plt.show()

# %%
from sklearn.model_selection import train_test_split

x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20433, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

# %%
train_data = x_train

# %%
x_train.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=((15,8)))
sns.heatmap(data[pd_data.coll].corr(),annot=True)
plt.show()

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] +1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] +1)
train_data['population'] = np.log(train_data['population'] +1)
train_data['households'] = np.log(train_data['households'] +1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x='latitude', y='longitude',  data= train_data, hue='housing_median_age', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
def tran_ocean(x):                          #Converting string into number
    if x =="<1H OCEAN":
        return 0
    if x == "INLAND":
        return 1
    if x == "NEAR OCEAN":
        return 2
    if x == "NEAR BAY":
        return 3
    if x == "ISLAND":
        return 4

# %%
pd_data['tran_ocean'] = pd_data['ocean_proximity'].apply(tran_ocean)
pd_data
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population
# 0                      41          880           129.0         322  \
# 1                      21         7099          1106.0        2401
# 2                      52         1467           190.0         496
# 3                      52         1274           235.0         558
# 4                      52         1627           280.0         565
# ...                   ...          ...             ...         ...
# 20635                  25         1665           374.0         845
# 20636                  18          697           150.0         356
# 20637                  17         2254           485.0        1007
# 20638                  18         1860           409.0         741
# 20639                  16         2785           616.0        1387
#
#        households  median_income ocean_proximity  median_house_value
# 0             126         8.3252        NEAR BAY              452600  \
# ...

# %%
pd_data.drop(columns=['ocean_proximity'], inplace=True)

# %%
pd_data.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households
# 0                  41          880           129.0         322         126  \
# 1                  21         7099          1106.0        2401        1138
# 2                  52         1467           190.0         496         177
# 3                  52         1274           235.0         558         219
# 4                  52         1627           280.0         565         259
#
#    median_income  median_house_value  tran_ocean
# 0         8.3252              452600           3
# 1         8.3014              358500           3
# 2         7.2574              352100           3
# 3         5.6431              341300           3
# 4         3.8462              342200           3

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y = pd_data['median_house_value']
x = pd_data.drop('median_house_value', axis=1)

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2, random_state=42)

print(xtrain.shape, xtest.shape)
print(ytrain.shape, ytest.shape)
# Out:
# (16346, 7) (4087, 7)
# (16346,) (4087,)

# %%
lr = LinearRegression()
lr.fit(xtrain, ytrain)
y_pred = lr.predict(xtrain)

# %%
print('R2 Score',r2_score(ytrain, y_pred))
print()
print('Train Score:', lr.score(xtrain, ytrain))
print()
print('Test Score:', lr.score(xtest, ytest))
print()
print('MAE:', mean_absolute_error(ytrain, y_pred))
print()
print('MSE:', mean_squared_error(ytrain, y_pred))
print()
print('RMSE:', mean_squared_error(ytrain, y_pred, squared=False))
# Out:
# R2 Score 0.565552393404266
#
# Train Score: 0.565552393404266
#
# Test Score: 0.5711671027186057
#
# MAE: 55653.876638260095
#
# MSE: 5750730156.571284
#
# RMSE: 75833.56879754034
